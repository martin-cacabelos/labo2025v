# %% [markdown]
# <a href="https://colab.research.google.com/github/martin-cacabelos/labo2025v/blob/main/src/workflows/610_WorkFlow_01_gerencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Drive already mounted at /content/.drive; to attempt to forcibly remount, call drive.mount("/content/.drive", force_remount=True).

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# ln: failed to create symbolic link '/content/buckets/b1/labo1': File exists

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 11:08:35 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  709760 38.0 1454494    77.7 1454494  77.7
# Vcells 1315727 10.1 8388608    64.0 2065470  15.8

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 782611

PARAM$experimento <- 6300
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

cols_lagueables <- copy( setdiff(
  colnames(dataset),
  c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# me guardo las columnas originales para no laguear lags sobre lags
base_cols <- copy(cols_lagueables)

# ordenes de lag que quiero crear
ordenes_lag <- c(1, 2, 3, 6, 12)

# creo lags y deltas para cada orden
for(k in ordenes_lag) {

  # lags de orden k
  dataset[,
    (paste0(base_cols, "_lag", k)) := shift(.SD, k, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = base_cols
  ]

  # agrego los delta lags de orden k
  for (vcol in base_cols) {
    dataset[, (paste0(vcol, "_delta", k)) :=
               get(vcol) - get(paste0(vcol, "_lag", k))]
  }
}

# verificación rápida
ncol(dataset)
colnames(dataset)
# Out:
# [1] 344
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "mcaja_ahorro"
#  [14] "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"
#  [16] "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"
#  [18] "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"
#  [20] "cpayroll_trx"
#  [21] "mpayroll"
#  [22] "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"
#  [24] "chomebanking_transacciones"
#  [25] "ctrx_quarter"
#  [26] "Master_status"
#  [27] "Master_fechaalta"
#  [28] "Master_mpagominimo"
#  [29] "Visa_status"
#  [30] "Visa_fechaalta"
#  [31] "Visa_mpagominimo"
#  [32] "clase_ternaria"
#  [33] "kmes"
#  [34] "mpayroll_sobre_edad"
#  [35] "internet_lag1"
#  [36] "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"
#  [38] "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"
#  [40] "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"
#  [42] "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"
#  [44] "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"
#  [46] "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"
#  [48] "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"
#  [50] "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"
#  [52] "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"
#  [54] "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"
#  [56] "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"
#  [58] "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"
#  [60] "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"
#  [62] "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"
#  [64] "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"
#  [66] "internet_delta1"
#  [67] "cliente_edad_delta1"
#  [68] "cliente_antiguedad_delta1"
#  [69] "mrentabilidad_delta1"
#  [70] "mrentabilidad_annual_delta1"
#  [71] "mcomisiones_delta1"
#  [72] "mactivos_margen_delta1"
#  [73] "mpasivos_margen_delta1"
#  [74] "cproductos_delta1"
#  [75] "mcuenta_corriente_delta1"
#  [76] "mcaja_ahorro_delta1"
#  [77] "cdescubierto_preacordado_delta1"
#  [78] "mcuentas_saldo_delta1"
#  [79] "ctarjeta_visa_transacciones_delta1"
#  [80] "mtarjeta_visa_consumo_delta1"
#  [81] "mtarjeta_master_consumo_delta1"
#  [82] "mprestamos_personales_delta1"
#  [83] "cpayroll_trx_delta1"
#  [84] "mpayroll_delta1"
#  [85] "ccomisiones_mantenimiento_delta1"
#  [86] "ccallcenter_transacciones_delta1"
#  [87] "chomebanking_transacciones_delta1"
#  [88] "ctrx_quarter_delta1"
#  [89] "Master_status_delta1"
#  [90] "Master_fechaalta_delta1"
#  [91] "Master_mpagominimo_delta1"
#  [92] "Visa_status_delta1"
#  [93] "Visa_fechaalta_delta1"
#  [94] "Visa_mpagominimo_delta1"
#  [95] "kmes_delta1"
#  [96] "mpayroll_sobre_edad_delta1"
#  [97] "internet_lag2"
#  [98] "cliente_edad_lag2"
#  [99] "cliente_antiguedad_lag2"
# [100] "mrentabilidad_lag2"
# [101] "mrentabilidad_annual_lag2"
# [102] "mcomisiones_lag2"
# [103] "mactivos_margen_lag2"
# [104] "mpasivos_margen_lag2"
# [105] "cproductos_lag2"
# [106] "mcuenta_corriente_lag2"
# [107] "mcaja_ahorro_lag2"
# [108] "cdescubierto_preacordado_lag2"
# [109] "mcuentas_saldo_lag2"
# [110] "ctarjeta_visa_transacciones_lag2"
# [111] "mtarjeta_visa_consumo_lag2"
# [112] "mtarjeta_master_consumo_lag2"
# [113] "mprestamos_personales_lag2"
# [114] "cpayroll_trx_lag2"
# [115] "mpayroll_lag2"
# [116] "ccomisiones_mantenimiento_lag2"
# [117] "ccallcenter_transacciones_lag2"
# [118] "chomebanking_transacciones_lag2"
# [119] "ctrx_quarter_lag2"
# [120] "Master_status_lag2"
# [121] "Master_fechaalta_lag2"
# [122] "Master_mpagominimo_lag2"
# [123] "Visa_status_lag2"
# [124] "Visa_fechaalta_lag2"
# [125] "Visa_mpagominimo_lag2"
# [126] "kmes_lag2"
# [127] "mpayroll_sobre_edad_lag2"
# [128] "internet_delta2"
# [129] "cliente_edad_delta2"
# [130] "cliente_antiguedad_delta2"
# [131] "mrentabilidad_delta2"
# [132] "mrentabilidad_annual_delta2"
# [133] "mcomisiones_delta2"
# [134] "mactivos_margen_delta2"
# [135] "mpasivos_margen_delta2"
# [136] "cproductos_delta2"
# [137] "mcuenta_corriente_delta2"
# [138] "mcaja_ahorro_delta2"
# [139] "cdescubierto_preacordado_delta2"
# [140] "mcuentas_saldo_delta2"
# [141] "ctarjeta_visa_transacciones_delta2"
# [142] "mtarjeta_visa_consumo_delta2"
# [143] "mtarjeta_master_consumo_delta2"
# [144] "mprestamos_personales_delta2"
# [145] "cpayroll_trx_delta2"
# [146] "mpayroll_delta2"
# [147] "ccomisiones_mantenimiento_delta2"
# [148] "ccallcenter_transacciones_delta2"
# [149] "chomebanking_transacciones_delta2"
# [150] "ctrx_quarter_delta2"
# [151] "Master_status_delta2"
# [152] "Master_fechaalta_delta2"
# [153] "Master_mpagominimo_delta2"
# [154] "Visa_status_delta2"
# [155] "Visa_fechaalta_delta2"
# [156] "Visa_mpagominimo_delta2"
# [157] "kmes_delta2"
# [158] "mpayroll_sobre_edad_delta2"
# [159] "internet_lag3"
# [160] "cliente_edad_lag3"
# [161] "cliente_antiguedad_lag3"
# [162] "mrentabilidad_lag3"
# [163] "mrentabilidad_annual_lag3"
# [164] "mcomisiones_lag3"
# [165] "mactivos_margen_lag3"
# [166] "mpasivos_margen_lag3"
# [167] "cproductos_lag3"
# [168] "mcuenta_corriente_lag3"
# [169] "mcaja_ahorro_lag3"
# [170] "cdescubierto_preacordado_lag3"
# [171] "mcuentas_saldo_lag3"
# [172] "ctarjeta_visa_transacciones_lag3"
# [173] "mtarjeta_visa_consumo_lag3"
# [174] "mtarjeta_master_consumo_lag3"
# [175] "mprestamos_personales_lag3"
# [176] "cpayroll_trx_lag3"
# [177] "mpayroll_lag3"
# [178] "ccomisiones_mantenimiento_lag3"
# [179] "ccallcenter_transacciones_lag3"
# [180] "chomebanking_transacciones_lag3"
# [181] "ctrx_quarter_lag3"
# [182] "Master_status_lag3"
# [183] "Master_fechaalta_lag3"
# [184] "Master_mpagominimo_lag3"
# [185] "Visa_status_lag3"
# [186] "Visa_fechaalta_lag3"
# [187] "Visa_mpagominimo_lag3"
# [188] "kmes_lag3"
# [189] "mpayroll_sobre_edad_lag3"
# [190] "internet_delta3"
# [191] "cliente_edad_delta3"
# [192] "cliente_antiguedad_delta3"
# [193] "mrentabilidad_delta3"
# [194] "mrentabilidad_annual_delta3"
# [195] "mcomisiones_delta3"
# [196] "mactivos_margen_delta3"
# [197] "mpasivos_margen_delta3"
# [198] "cproductos_delta3"
# [199] "mcuenta_corriente_delta3"
# [200] "mcaja_ahorro_delta3"
# [201] "cdescubierto_preacordado_delta3"
# [202] "mcuentas_saldo_delta3"
# [203] "ctarjeta_visa_transacciones_delta3"
# [204] "mtarjeta_visa_consumo_delta3"
# [205] "mtarjeta_master_consumo_delta3"
# [206] "mprestamos_personales_delta3"
# [207] "cpayroll_trx_delta3"
# [208] "mpayroll_delta3"
# [209] "ccomisiones_mantenimiento_delta3"
# [210] "ccallcenter_transacciones_delta3"
# [211] "chomebanking_transacciones_delta3"
# [212] "ctrx_quarter_delta3"
# [213] "Master_status_delta3"
# [214] "Master_fechaalta_delta3"
# [215] "Master_mpagominimo_delta3"
# [216] "Visa_status_delta3"
# [217] "Visa_fechaalta_delta3"
# [218] "Visa_mpagominimo_delta3"
# [219] "kmes_delta3"
# [220] "mpayroll_sobre_edad_delta3"
# [221] "internet_lag6"
# [222] "cliente_edad_lag6"
# [223] "cliente_antiguedad_lag6"
# [224] "mrentabilidad_lag6"
# [225] "mrentabilidad_annual_lag6"
# [226] "mcomisiones_lag6"
# [227] "mactivos_margen_lag6"
# [228] "mpasivos_margen_lag6"
# [229] "cproductos_lag6"
# [230] "mcuenta_corriente_lag6"
# [231] "mcaja_ahorro_lag6"
# [232] "cdescubierto_preacordado_lag6"
# [233] "mcuentas_saldo_lag6"
# [234] "ctarjeta_visa_transacciones_lag6"
# [235] "mtarjeta_visa_consumo_lag6"
# [236] "mtarjeta_master_consumo_lag6"
# [237] "mprestamos_personales_lag6"
# [238] "cpayroll_trx_lag6"
# [239] "mpayroll_lag6"
# [240] "ccomisiones_mantenimiento_lag6"
# [241] "ccallcenter_transacciones_lag6"
# [242] "chomebanking_transacciones_lag6"
# [243] "ctrx_quarter_lag6"
# [244] "Master_status_lag6"
# [245] "Master_fechaalta_lag6"
# [246] "Master_mpagominimo_lag6"
# [247] "Visa_status_lag6"
# [248] "Visa_fechaalta_lag6"
# [249] "Visa_mpagominimo_lag6"
# [250] "kmes_lag6"
# [251] "mpayroll_sobre_edad_lag6"
# [252] "internet_delta6"
# [253] "cliente_edad_delta6"
# [254] "cliente_antiguedad_delta6"
# [255] "mrentabilidad_delta6"
# [256] "mrentabilidad_annual_delta6"
# [257] "mcomisiones_delta6"
# [258] "mactivos_margen_delta6"
# [259] "mpasivos_margen_delta6"
# [260] "cproductos_delta6"
# [261] "mcuenta_corriente_delta6"
# [262] "mcaja_ahorro_delta6"
# [263] "cdescubierto_preacordado_delta6"
# [264] "mcuentas_saldo_delta6"
# [265] "ctarjeta_visa_transacciones_delta6"
# [266] "mtarjeta_visa_consumo_delta6"
# [267] "mtarjeta_master_consumo_delta6"
# [268] "mprestamos_personales_delta6"
# [269] "cpayroll_trx_delta6"
# [270] "mpayroll_delta6"
# [271] "ccomisiones_mantenimiento_delta6"
# [272] "ccallcenter_transacciones_delta6"
# [273] "chomebanking_transacciones_delta6"
# [274] "ctrx_quarter_delta6"
# [275] "Master_status_delta6"
# [276] "Master_fechaalta_delta6"
# [277] "Master_mpagominimo_delta6"
# [278] "Visa_status_delta6"
# [279] "Visa_fechaalta_delta6"
# [280] "Visa_mpagominimo_delta6"
# [281] "kmes_delta6"
# [282] "mpayroll_sobre_edad_delta6"
# [283] "internet_lag12"
# [284] "cliente_edad_lag12"
# [285] "cliente_antiguedad_lag12"
# [286] "mrentabilidad_lag12"
# [287] "mrentabilidad_annual_lag12"
# [288] "mcomisiones_lag12"
# [289] "mactivos_margen_lag12"
# [290] "mpasivos_margen_lag12"
# [291] "cproductos_lag12"
# [292] "mcuenta_corriente_lag12"
# [293] "mcaja_ahorro_lag12"
# [294] "cdescubierto_preacordado_lag12"
# [295] "mcuentas_saldo_lag12"
# [296] "ctarjeta_visa_transacciones_lag12"
# [297] "mtarjeta_visa_consumo_lag12"
# [298] "mtarjeta_master_consumo_lag12"
# [299] "mprestamos_personales_lag12"
# [300] "cpayroll_trx_lag12"
# [301] "mpayroll_lag12"
# [302] "ccomisiones_mantenimiento_lag12"
# [303] "ccallcenter_transacciones_lag12"
# [304] "chomebanking_transacciones_lag12"
# [305] "ctrx_quarter_lag12"
# [306] "Master_status_lag12"
# [307] "Master_fechaalta_lag12"
# [308] "Master_mpagominimo_lag12"
# [309] "Visa_status_lag12"
# [310] "Visa_fechaalta_lag12"
# [311] "Visa_mpagominimo_lag12"
# [312] "kmes_lag12"
# [313] "mpayroll_sobre_edad_lag12"
# [314] "internet_delta12"
# [315] "cliente_edad_delta12"
# [316] "cliente_antiguedad_delta12"
# [317] "mrentabilidad_delta12"
# [318] "mrentabilidad_annual_delta12"
# [319] "mcomisiones_delta12"
# [320] "mactivos_margen_delta12"
# [321] "mpasivos_margen_delta12"
# [322] "cproductos_delta12"
# [323] "mcuenta_corriente_delta12"
# [324] "mcaja_ahorro_delta12"
# [325] "cdescubierto_preacordado_delta12"
# [326] "mcuentas_saldo_delta12"
# [327] "ctarjeta_visa_transacciones_delta12"
# [328] "mtarjeta_visa_consumo_delta12"
# [329] "mtarjeta_master_consumo_delta12"
# [330] "mprestamos_personales_delta12"
# [331] "cpayroll_trx_delta12"
# [332] "mpayroll_delta12"
# [333] "ccomisiones_mantenimiento_delta12"
# [334] "ccallcenter_transacciones_delta12"
# [335] "chomebanking_transacciones_delta12"
# [336] "ctrx_quarter_delta12"
# [337] "Master_status_delta12"
# [338] "Master_fechaalta_delta12"
# [339] "Master_mpagominimo_delta12"
# [340] "Visa_status_delta12"
# [341] "Visa_fechaalta_delta12"
# [342] "Visa_mpagominimo_delta12"
# [343] "kmes_delta12"
# [344] "mpayroll_sobre_edad_delta12"

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 344
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "mcaja_ahorro"
#  [14] "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"
#  [16] "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"
#  [18] "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"
#  [20] "cpayroll_trx"
#  [21] "mpayroll"
#  [22] "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"
#  [24] "chomebanking_transacciones"
#  [25] "ctrx_quarter"
#  [26] "Master_status"
#  [27] "Master_fechaalta"
#  [28] "Master_mpagominimo"
#  [29] "Visa_status"
#  [30] "Visa_fechaalta"
#  [31] "Visa_mpagominimo"
#  [32] "clase_ternaria"
#  [33] "kmes"
#  [34] "mpayroll_sobre_edad"
#  [35] "internet_lag1"
#  [36] "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"
#  [38] "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"
#  [40] "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"
#  [42] "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"
#  [44] "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"
#  [46] "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"
#  [48] "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"
#  [50] "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"
#  [52] "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"
#  [54] "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"
#  [56] "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"
#  [58] "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"
#  [60] "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"
#  [62] "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"
#  [64] "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"
#  [66] "internet_delta1"
#  [67] "cliente_edad_delta1"
#  [68] "cliente_antiguedad_delta1"
#  [69] "mrentabilidad_delta1"
#  [70] "mrentabilidad_annual_delta1"
#  [71] "mcomisiones_delta1"
#  [72] "mactivos_margen_delta1"
#  [73] "mpasivos_margen_delta1"
#  [74] "cproductos_delta1"
#  [75] "mcuenta_corriente_delta1"
#  [76] "mcaja_ahorro_delta1"
#  [77] "cdescubierto_preacordado_delta1"
#  [78] "mcuentas_saldo_delta1"
#  [79] "ctarjeta_visa_transacciones_delta1"
#  [80] "mtarjeta_visa_consumo_delta1"
#  [81] "mtarjeta_master_consumo_delta1"
#  [82] "mprestamos_personales_delta1"
#  [83] "cpayroll_trx_delta1"
#  [84] "mpayroll_delta1"
#  [85] "ccomisiones_mantenimiento_delta1"
#  [86] "ccallcenter_transacciones_delta1"
#  [87] "chomebanking_transacciones_delta1"
#  [88] "ctrx_quarter_delta1"
#  [89] "Master_status_delta1"
#  [90] "Master_fechaalta_delta1"
#  [91] "Master_mpagominimo_delta1"
#  [92] "Visa_status_delta1"
#  [93] "Visa_fechaalta_delta1"
#  [94] "Visa_mpagominimo_delta1"
#  [95] "kmes_delta1"
#  [96] "mpayroll_sobre_edad_delta1"
#  [97] "internet_lag2"
#  [98] "cliente_edad_lag2"
#  [99] "cliente_antiguedad_lag2"
# [100] "mrentabilidad_lag2"
# [101] "mrentabilidad_annual_lag2"
# [102] "mcomisiones_lag2"
# [103] "mactivos_margen_lag2"
# [104] "mpasivos_margen_lag2"
# [105] "cproductos_lag2"
# [106] "mcuenta_corriente_lag2"
# [107] "mcaja_ahorro_lag2"
# [108] "cdescubierto_preacordado_lag2"
# [109] "mcuentas_saldo_lag2"
# [110] "ctarjeta_visa_transacciones_lag2"
# [111] "mtarjeta_visa_consumo_lag2"
# [112] "mtarjeta_master_consumo_lag2"
# [113] "mprestamos_personales_lag2"
# [114] "cpayroll_trx_lag2"
# [115] "mpayroll_lag2"
# [116] "ccomisiones_mantenimiento_lag2"
# [117] "ccallcenter_transacciones_lag2"
# [118] "chomebanking_transacciones_lag2"
# [119] "ctrx_quarter_lag2"
# [120] "Master_status_lag2"
# [121] "Master_fechaalta_lag2"
# [122] "Master_mpagominimo_lag2"
# [123] "Visa_status_lag2"
# [124] "Visa_fechaalta_lag2"
# [125] "Visa_mpagominimo_lag2"
# [126] "kmes_lag2"
# [127] "mpayroll_sobre_edad_lag2"
# [128] "internet_delta2"
# [129] "cliente_edad_delta2"
# [130] "cliente_antiguedad_delta2"
# [131] "mrentabilidad_delta2"
# [132] "mrentabilidad_annual_delta2"
# [133] "mcomisiones_delta2"
# [134] "mactivos_margen_delta2"
# [135] "mpasivos_margen_delta2"
# [136] "cproductos_delta2"
# [137] "mcuenta_corriente_delta2"
# [138] "mcaja_ahorro_delta2"
# [139] "cdescubierto_preacordado_delta2"
# [140] "mcuentas_saldo_delta2"
# [141] "ctarjeta_visa_transacciones_delta2"
# [142] "mtarjeta_visa_consumo_delta2"
# [143] "mtarjeta_master_consumo_delta2"
# [144] "mprestamos_personales_delta2"
# [145] "cpayroll_trx_delta2"
# [146] "mpayroll_delta2"
# [147] "ccomisiones_mantenimiento_delta2"
# [148] "ccallcenter_transacciones_delta2"
# [149] "chomebanking_transacciones_delta2"
# [150] "ctrx_quarter_delta2"
# [151] "Master_status_delta2"
# [152] "Master_fechaalta_delta2"
# [153] "Master_mpagominimo_delta2"
# [154] "Visa_status_delta2"
# [155] "Visa_fechaalta_delta2"
# [156] "Visa_mpagominimo_delta2"
# [157] "kmes_delta2"
# [158] "mpayroll_sobre_edad_delta2"
# [159] "internet_lag3"
# [160] "cliente_edad_lag3"
# [161] "cliente_antiguedad_lag3"
# [162] "mrentabilidad_lag3"
# [163] "mrentabilidad_annual_lag3"
# [164] "mcomisiones_lag3"
# [165] "mactivos_margen_lag3"
# [166] "mpasivos_margen_lag3"
# [167] "cproductos_lag3"
# [168] "mcuenta_corriente_lag3"
# [169] "mcaja_ahorro_lag3"
# [170] "cdescubierto_preacordado_lag3"
# [171] "mcuentas_saldo_lag3"
# [172] "ctarjeta_visa_transacciones_lag3"
# [173] "mtarjeta_visa_consumo_lag3"
# [174] "mtarjeta_master_consumo_lag3"
# [175] "mprestamos_personales_lag3"
# [176] "cpayroll_trx_lag3"
# [177] "mpayroll_lag3"
# [178] "ccomisiones_mantenimiento_lag3"
# [179] "ccallcenter_transacciones_lag3"
# [180] "chomebanking_transacciones_lag3"
# [181] "ctrx_quarter_lag3"
# [182] "Master_status_lag3"
# [183] "Master_fechaalta_lag3"
# [184] "Master_mpagominimo_lag3"
# [185] "Visa_status_lag3"
# [186] "Visa_fechaalta_lag3"
# [187] "Visa_mpagominimo_lag3"
# [188] "kmes_lag3"
# [189] "mpayroll_sobre_edad_lag3"
# [190] "internet_delta3"
# [191] "cliente_edad_delta3"
# [192] "cliente_antiguedad_delta3"
# [193] "mrentabilidad_delta3"
# [194] "mrentabilidad_annual_delta3"
# [195] "mcomisiones_delta3"
# [196] "mactivos_margen_delta3"
# [197] "mpasivos_margen_delta3"
# [198] "cproductos_delta3"
# [199] "mcuenta_corriente_delta3"
# [200] "mcaja_ahorro_delta3"
# [201] "cdescubierto_preacordado_delta3"
# [202] "mcuentas_saldo_delta3"
# [203] "ctarjeta_visa_transacciones_delta3"
# [204] "mtarjeta_visa_consumo_delta3"
# [205] "mtarjeta_master_consumo_delta3"
# [206] "mprestamos_personales_delta3"
# [207] "cpayroll_trx_delta3"
# [208] "mpayroll_delta3"
# [209] "ccomisiones_mantenimiento_delta3"
# [210] "ccallcenter_transacciones_delta3"
# [211] "chomebanking_transacciones_delta3"
# [212] "ctrx_quarter_delta3"
# [213] "Master_status_delta3"
# [214] "Master_fechaalta_delta3"
# [215] "Master_mpagominimo_delta3"
# [216] "Visa_status_delta3"
# [217] "Visa_fechaalta_delta3"
# [218] "Visa_mpagominimo_delta3"
# [219] "kmes_delta3"
# [220] "mpayroll_sobre_edad_delta3"
# [221] "internet_lag6"
# [222] "cliente_edad_lag6"
# [223] "cliente_antiguedad_lag6"
# [224] "mrentabilidad_lag6"
# [225] "mrentabilidad_annual_lag6"
# [226] "mcomisiones_lag6"
# [227] "mactivos_margen_lag6"
# [228] "mpasivos_margen_lag6"
# [229] "cproductos_lag6"
# [230] "mcuenta_corriente_lag6"
# [231] "mcaja_ahorro_lag6"
# [232] "cdescubierto_preacordado_lag6"
# [233] "mcuentas_saldo_lag6"
# [234] "ctarjeta_visa_transacciones_lag6"
# [235] "mtarjeta_visa_consumo_lag6"
# [236] "mtarjeta_master_consumo_lag6"
# [237] "mprestamos_personales_lag6"
# [238] "cpayroll_trx_lag6"
# [239] "mpayroll_lag6"
# [240] "ccomisiones_mantenimiento_lag6"
# [241] "ccallcenter_transacciones_lag6"
# [242] "chomebanking_transacciones_lag6"
# [243] "ctrx_quarter_lag6"
# [244] "Master_status_lag6"
# [245] "Master_fechaalta_lag6"
# [246] "Master_mpagominimo_lag6"
# [247] "Visa_status_lag6"
# [248] "Visa_fechaalta_lag6"
# [249] "Visa_mpagominimo_lag6"
# [250] "kmes_lag6"
# [251] "mpayroll_sobre_edad_lag6"
# [252] "internet_delta6"
# [253] "cliente_edad_delta6"
# [254] "cliente_antiguedad_delta6"
# [255] "mrentabilidad_delta6"
# [256] "mrentabilidad_annual_delta6"
# [257] "mcomisiones_delta6"
# [258] "mactivos_margen_delta6"
# [259] "mpasivos_margen_delta6"
# [260] "cproductos_delta6"
# [261] "mcuenta_corriente_delta6"
# [262] "mcaja_ahorro_delta6"
# [263] "cdescubierto_preacordado_delta6"
# [264] "mcuentas_saldo_delta6"
# [265] "ctarjeta_visa_transacciones_delta6"
# [266] "mtarjeta_visa_consumo_delta6"
# [267] "mtarjeta_master_consumo_delta6"
# [268] "mprestamos_personales_delta6"
# [269] "cpayroll_trx_delta6"
# [270] "mpayroll_delta6"
# [271] "ccomisiones_mantenimiento_delta6"
# [272] "ccallcenter_transacciones_delta6"
# [273] "chomebanking_transacciones_delta6"
# [274] "ctrx_quarter_delta6"
# [275] "Master_status_delta6"
# [276] "Master_fechaalta_delta6"
# [277] "Master_mpagominimo_delta6"
# [278] "Visa_status_delta6"
# [279] "Visa_fechaalta_delta6"
# [280] "Visa_mpagominimo_delta6"
# [281] "kmes_delta6"
# [282] "mpayroll_sobre_edad_delta6"
# [283] "internet_lag12"
# [284] "cliente_edad_lag12"
# [285] "cliente_antiguedad_lag12"
# [286] "mrentabilidad_lag12"
# [287] "mrentabilidad_annual_lag12"
# [288] "mcomisiones_lag12"
# [289] "mactivos_margen_lag12"
# [290] "mpasivos_margen_lag12"
# [291] "cproductos_lag12"
# [292] "mcuenta_corriente_lag12"
# [293] "mcaja_ahorro_lag12"
# [294] "cdescubierto_preacordado_lag12"
# [295] "mcuentas_saldo_lag12"
# [296] "ctarjeta_visa_transacciones_lag12"
# [297] "mtarjeta_visa_consumo_lag12"
# [298] "mtarjeta_master_consumo_lag12"
# [299] "mprestamos_personales_lag12"
# [300] "cpayroll_trx_lag12"
# [301] "mpayroll_lag12"
# [302] "ccomisiones_mantenimiento_lag12"
# [303] "ccallcenter_transacciones_lag12"
# [304] "chomebanking_transacciones_lag12"
# [305] "ctrx_quarter_lag12"
# [306] "Master_status_lag12"
# [307] "Master_fechaalta_lag12"
# [308] "Master_mpagominimo_lag12"
# [309] "Visa_status_lag12"
# [310] "Visa_fechaalta_lag12"
# [311] "Visa_mpagominimo_lag12"
# [312] "kmes_lag12"
# [313] "mpayroll_sobre_edad_lag12"
# [314] "internet_delta12"
# [315] "cliente_edad_delta12"
# [316] "cliente_antiguedad_delta12"
# [317] "mrentabilidad_delta12"
# [318] "mrentabilidad_annual_delta12"
# [319] "mcomisiones_delta12"
# [320] "mactivos_margen_delta12"
# [321] "mpasivos_margen_delta12"
# [322] "cproductos_delta12"
# [323] "mcuenta_corriente_delta12"
# [324] "mcaja_ahorro_delta12"
# [325] "cdescubierto_preacordado_delta12"
# [326] "mcuentas_saldo_delta12"
# [327] "ctarjeta_visa_transacciones_delta12"
# [328] "mtarjeta_visa_consumo_delta12"
# [329] "mtarjeta_master_consumo_delta12"
# [330] "mprestamos_personales_delta12"
# [331] "cpayroll_trx_delta12"
# [332] "mpayroll_delta12"
# [333] "ccomisiones_mantenimiento_delta12"
# [334] "ccallcenter_transacciones_delta12"
# [335] "chomebanking_transacciones_delta12"
# [336] "ctrx_quarter_delta12"
# [337] "Master_status_delta12"
# [338] "Master_fechaalta_delta12"
# [339] "Master_mpagominimo_delta12"
# [340] "Visa_status_delta12"
# [341] "Visa_fechaalta_delta12"
# [342] "Visa_mpagominimo_delta12"
# [343] "kmes_delta12"
# [344] "mpayroll_sobre_edad_delta12"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(   202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 20

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.03,
  feature_fraction= 0.5,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower = 2L, upper = 256L),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
if( file.exists("HT.RDATA") ) file.remove("HT.RDATA")
if( file.exists("BO_log.txt") ) file.remove("BO_log.txt")
# Out:
# [1] TRUE
# [1] TRUE

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 30 11:18:54 PM 2025 AUC 0.940604723356881
#
# Sun Nov 30 11:24:41 PM 2025 AUC 0.92719953240203
#
# Sun Nov 30 11:35:22 PM 2025 AUC 0.934571179510512
#
# Sun Nov 30 11:44:14 PM 2025 AUC 0.938657964298009
#
# Sun Nov 30 11:52:11 PM 2025 AUC 0.933770599173651
#
# Mon Dec 01 12:01:27 AM 2025 AUC 0.926987811449574
#
# Mon Dec 01 12:09:48 AM 2025 AUC 0.929057710903931
#
# Mon Dec 01 12:14:27 AM 2025 AUC 0.933596122319012
#
# [mbo] 0: num_leaves=105; min_data_in_leaf=1841 : y = 0.941 : 549.4 secs : initdesign
#
# [mbo] 0: num_leaves=170; min_data_in_leaf=6902 : y = 0.927 : 347.2 secs : initdesign
#
# [mbo] 0: num_leaves=92; min_data_in_leaf=4476 : y = 0.935 : 641.2 secs : initdesign
#
# [mbo] 0: num_leaves=129; min_data_in_leaf=2075 : y = 0.939 : 531.7 secs : initdesign
#
# [mbo] 0: num_leaves=245; min_data_in_leaf=3297 : y = 0.934 : 477.4 secs : initdesign
#
# [mbo] 0: num_leaves=10; min_data_in_leaf=5856 : y = 0.927 : 555.6 secs : initdesign
#
# [mbo] 0: num_leaves=220; min_data_in_leaf=7468 : y = 0.929 : 500.6 secs : initdesign
#
# [mbo] 0: num_leaves=59; min_data_in_leaf=24 : y = 0.934 : 279.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Mon Dec 01 12:22:38 AM 2025 AUC 0.91229736358762
#
# [mbo] 1: num_leaves=2; min_data_in_leaf=1581 : y = 0.912 : 490.7 secs : infill_ei
#
# Mon Dec 01 12:26:58 AM 2025 AUC 0.935785471312314
#
# [mbo] 2: num_leaves=110; min_data_in_leaf=116 : y = 0.936 : 259.8 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Mon Dec 01 12:37:18 AM 2025 AUC 0.93977025424633
#
# [mbo] 3: num_leaves=111; min_data_in_leaf=2675 : y = 0.94 : 619.3 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Mon Dec 01 12:45:43 AM 2025 AUC 0.938136211396157
#
# [mbo] 4: num_leaves=90; min_data_in_leaf=2083 : y = 0.938 : 504.4 secs : infill_ei
#
# Mon Dec 01 12:51:02 AM 2025 AUC 0.938323438482481
#
# [mbo] 5: num_leaves=114; min_data_in_leaf=1843 : y = 0.938 : 318.7 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Mon Dec 01 01:02:29 AM 2025 AUC 0.939165289306112
#
# [mbo] 6: num_leaves=103; min_data_in_leaf=2462 : y = 0.939 : 687.0 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Mon Dec 01 01:11:48 AM 2025 AUC 0.934093716887145
#
# [mbo] 7: num_leaves=128; min_data_in_leaf=4494 : y = 0.934 : 558.0 secs : infill_ei
#
# Mon Dec 01 01:20:21 AM 2025 AUC 0.938976384557725
#
# [mbo] 8: num_leaves=144; min_data_in_leaf=1911 : y = 0.939 : 513.1 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Mon Dec 01 01:27:07 AM 2025 AUC 0.945041468450894
#
# [mbo] 9: num_leaves=160; min_data_in_leaf=406 : y = 0.945 : 405.9 secs : infill_ei
#
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 646 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 846 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 781 points instead of 1000!”
# Mon Dec 01 01:30:27 AM 2025 AUC 0.939290107363661
#
# [mbo] 10: num_leaves=170; min_data_in_leaf=2 : y = 0.939 : 199.1 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 864 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 765 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 906 points instead of 1000!”
# Mon Dec 01 01:34:42 AM 2025 AUC 0.939266620094768
#
# [mbo] 11: num_leaves=155; min_data_in_leaf=2 : y = 0.939 : 254.2 secs : infill_ei
#
# Mon Dec 01 01:42:47 AM 2025 AUC 0.943223553838524
#
# [mbo] 12: num_leaves=162; min_data_in_leaf=767 : y = 0.943 : 484.9 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Mon Dec 01 01:49:20 AM 2025 AUC 0.942371301510097
#
# [mbo] 13: num_leaves=148; min_data_in_leaf=530 : y = 0.942 : 392.4 secs : infill_ei
#
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 794 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 705 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 809 points instead of 1000!”
# Mon Dec 01 01:54:14 AM 2025 AUC 0.937569497150994
#
# [mbo] 14: num_leaves=161; min_data_in_leaf=2 : y = 0.938 : 293.7 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Mon Dec 01 02:01:55 AM 2025 AUC 0.940903011671831
#
# [mbo] 15: num_leaves=174; min_data_in_leaf=466 : y = 0.941 : 460.6 secs : infill_ei
#
# Mon Dec 01 02:11:45 AM 2025 AUC 0.944100971097909
#
# [mbo] 16: num_leaves=156; min_data_in_leaf=469 : y = 0.944 : 589.4 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Mon Dec 01 02:17:47 AM 2025 AUC 0.943556066459576
#
# [mbo] 17: num_leaves=152; min_data_in_leaf=317 : y = 0.944 : 361.8 secs : infill_ei
#
# Mon Dec 01 02:26:35 AM 2025 AUC 0.938982088608742
#
# [mbo] 18: num_leaves=159; min_data_in_leaf=1484 : y = 0.939 : 527.5 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Mon Dec 01 02:34:12 AM 2025 AUC 0.940233624508361
#
# [mbo] 19: num_leaves=160; min_data_in_leaf=1211 : y = 0.94 : 456.8 secs : infill_ei
#
# Mon Dec 01 02:40:31 AM 2025 AUC 0.941174792926171
#
# [mbo] 20: num_leaves=208; min_data_in_leaf=466 : y = 0.941 : 378.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf num_iterations
#         <int>            <int>          <int>
# 1:        160              406            878

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 240562

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Warning message in dir.create("kaggle"):
# “'kaggle' already exists”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Dec 01 02:48:32 AM 2025"
